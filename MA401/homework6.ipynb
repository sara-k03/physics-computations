# %%
# Question 1b

import sympy as sp

s, t = sp.symbols('s t')

f = sp.E ** ( sp.Rational( -4, 3 ) * s ) * sp.Rational( 1, 3 ) * s * sp.sin( s )

definite_integral = sp.integrate(f, (s, 0, t))
definite_integral
# Out:
#        -4⋅t                -4⋅t                     -4⋅t               -4⋅t    ↪
#        ─────               ─────                    ─────              ─────   ↪
#          3                   3                        3                  3     ↪
#   4⋅t⋅ℯ     ⋅sin(t)   3⋅t⋅ℯ     ⋅cos(t)   72    21⋅ℯ     ⋅sin(t)   72⋅ℯ     ⋅c ↪
# - ───────────────── - ───────────────── + ─── - ──────────────── - ─────────── ↪
#          25                  25           625         625                625   ↪
#
# ↪
# ↪
# ↪
# ↪ os(t)
# ↪ ─────
# ↪
